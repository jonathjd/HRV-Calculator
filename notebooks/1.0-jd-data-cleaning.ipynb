# %%
import xml.etree.ElementTree as ET
import datetime as dt
import pandas as pd

# %%
# tree = ET.parse('/Users/dickinsonjo/repos/HRV-Calculator/data/export.xml')

# root = tree.getroot()
# record_list = [x.attrib for x in root.iter('Record')]
# Out:
# Traceback (most recent call last):
#
#   File ~/miniconda3/envs/.venv/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3460 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[8], line 1
#     tree = ET.parse('/Users/dickinsonjo/repos/HRV-Calculator/data/export.xml')
#
#   File ~/miniconda3/envs/.venv/lib/python3.8/xml/etree/ElementTree.py:1202 in parse
#     tree.parse(source, parser)
#
#   File ~/miniconda3/envs/.venv/lib/python3.8/xml/etree/ElementTree.py:595 in parse
#     self._root = parser._parse_whole(source)
#
#   File <string>
# ParseError: syntax error: line 156, column 0

# %%
ET.fromstring(open('/Users/dickinsonjo/repos/HRV-Calculator/data/export.xml').read())
# Out:
# Traceback (most recent call last):
#
#   File ~/miniconda3/envs/.venv/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3460 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 1
#     ET.fromstring(open('/Users/dickinsonjo/repos/HRV-Calculator/data/export.xml').read())
#
#   File ~/miniconda3/envs/.venv/lib/python3.8/xml/etree/ElementTree.py:1320 in XML
#     parser.feed(text)
#
#   File <string>
# ParseError: syntax error: line 156, column 0

# %%
df = pd.read_xml('/Users/dickinsonjo/repos/HRV-Calculator/data/export.xml')

# %%
df.describe()
# Out:
#        MetadataEntry    duration  WorkoutEvent  WorkoutStatistics  \
# count            0.0  234.000000           0.0                0.0
# mean             NaN   32.664300           NaN                NaN
# std              NaN   25.592954           NaN                NaN
# min              NaN    1.455924           NaN                NaN
# 25%              NaN   18.524676           NaN                NaN
# 50%              NaN   26.775314           NaN                NaN
# 75%              NaN   41.100140           NaN                NaN
# max              NaN  252.883333           NaN                NaN
#
#        WorkoutRoute  activeEnergyBurned  activeEnergyBurnedGoal  \
# count           0.0          192.000000              192.000000
# mean            NaN          579.513573              825.468750
# std             NaN          398.977548              135.487443
# min             NaN            0.000000                0.000000
# 25%             NaN          281.548750              850.000000
# 50%             NaN          624.324500              850.000000
# 75%             NaN          834.042000              850.000000
# max             NaN         2285.680000              850.000000
#
#        appleMoveTime  appleMoveTimeGoal  appleExerciseTime  \
# count          192.0              192.0         192.000000
# mean             0.0                0.0          41.291667
# std              0.0                0.0          38.107018
# min              0.0                0.0           0.000000
# 25%              0.0                0.0           7.000000
# 50%              0.0                0.0          35.000000
# 75%              0.0                0.0          68.000000
# max              0.0                0.0         244.000000
#
#        appleExerciseTimeGoal  appleStandHours  appleStandHoursGoal  \
# count             192.000000       192.000000                192.0
# mean               53.750000         8.203125                 12.0
# std                 4.219129         5.007365                  0.0
# min                30.000000         0.000000                 12.0
# 25%                55.000000         4.000000                 12.0
# 50%                55.000000        10.000000                 12.0
# 75%                55.000000        12.000000                 12.0
# max                55.000000        16.000000                 12.0
#
#        HeartRateVariabilityMetadataList
# count                               0.0
# mean                                NaN
# std                                 NaN
# min                                 NaN
# 25%                                 NaN
# 50%                                 NaN
# 75%                                 NaN
# max                                 NaN

# %%
df.columns
# Out:
# Index(['value', 'HKCharacteristicTypeIdentifierDateOfBirth',
#        'HKCharacteristicTypeIdentifierBiologicalSex',
#        'HKCharacteristicTypeIdentifierBloodType',
#        'HKCharacteristicTypeIdentifierFitzpatrickSkinType',
#        'HKCharacteristicTypeIdentifierCardioFitnessMedicationsUse', 'type',
#        'sourceName', 'sourceVersion', 'device', 'unit', 'creationDate',
#        'startDate', 'endDate', 'MetadataEntry', 'workoutActivityType',
#        'duration', 'durationUnit', 'WorkoutEvent', 'WorkoutStatistics',
#        'WorkoutRoute', 'dateComponents', 'activeEnergyBurned',
#        'activeEnergyBurnedGoal', 'activeEnergyBurnedUnit', 'appleMoveTime',
#        'appleMoveTimeGoal', 'appleExerciseTime', 'appleExerciseTimeGoal',
#        'appleStandHours', 'appleStandHoursGoal',
#        'HeartRateVariabilityMetadataList'],
#       dtype='object')

# %%
df.startDate.isnull().sum()
# Out:
# 194

# %%
date_cols = ['creationDate', 'startDate', 'endDate']

for col in date_cols:
    df[col] = pd.to_datetime(df[col])

# %%
df['type'] = df['type'].str.replace('HKQuantityTypeIdentifier', '')
df['type'] = df['type'].str.replace('HKCategoryTypeIdentifier', '')
df['workoutActivityType'] = df['workoutActivityType'].str.replace('HKWorkoutActivityType', '')

# %%
df['value'] = pd.to_numeric(df['value'], errors='coerce')
df['value'] = df['value'].fillna(1.0)

df['duration'] = pd.to_numeric(df['duration'])
df['activeEnergyBurned'] = pd.to_numeric(df['activeEnergyBurned'])

# %%
df['MetadataEntry'].unique()
# Out:
# array([nan])

# %%
df_cleaned = df.drop(columns=['HKCharacteristicTypeIdentifierFitzpatrickSkinType', 
                              'HeartRateVariabilityMetadataList', 
                              'HKCharacteristicTypeIdentifierCardioFitnessMedicationsUse',
                              'HKCharacteristicTypeIdentifierBloodType',
                              'HKCharacteristicTypeIdentifierBiologicalSex',
                              'HKCharacteristicTypeIdentifierDateOfBirth',
                              'WorkoutEvent',
                              'WorkoutRoute',
                              'WorkoutStatistics',
                              'MetadataEntry'
                              ]).copy()

# %%
df_cleaned.head()
# Out:
#      value          type  sourceName sourceVersion  \
# 0    1.000          None        None          None
# 1    1.000          None        None          None
# 2  131.320  DietaryWater  Cronometer          1050
# 3  162.087  DietaryWater  Cronometer          1115
# 4  162.087  DietaryWater  Cronometer          1115
#
#                                               device  unit  \
# 0                                               None  None
# 1                                               None  None
# 2  <<HKDevice: 0x280d46d50>, name:iPhone, manufac...    mL
# 3  <<HKDevice: 0x280d45270>, name:iPhone, manufac...    mL
# 4  <<HKDevice: 0x280d45270>, name:iPhone, manufac...    mL
#
#                creationDate                 startDate  \
# 0                       NaT                       NaT
# 1                       NaT                       NaT
# 2 2021-09-19 16:39:29-07:00 2021-09-20 00:00:00-07:00
# 3 2021-11-08 17:09:36-07:00 2021-11-08 01:00:00-07:00
# 4 2021-11-15 08:35:30-07:00 2021-11-15 01:00:00-07:00
#
#                     endDate workoutActivityType  ...  dateComponents  \
# 0                       NaT                None  ...            None
# 1                       NaT                None  ...            None
# 2 2021-09-20 00:00:00-07:00                None  ...            None
# 3 2021-11-08 01:00:00-07:00                None  ...            None
# 4 2021-11-15 01:00:00-07:00                None  ...            None
#
#   activeEnergyBurned activeEnergyBurnedGoal  activeEnergyBurnedUnit  \
# 0                NaN                    NaN                    None
# 1                NaN                    NaN                    None
# 2                NaN                    NaN                    None
# 3                NaN                    NaN                    None
# 4                NaN                    NaN                    None
#
#    appleMoveTime appleMoveTimeGoal  appleExerciseTime  appleExerciseTimeGoal  \
# 0            NaN               NaN                NaN                    NaN
# 1            NaN               NaN                NaN                    NaN
# 2            NaN               NaN                NaN                    NaN
# 3            NaN               NaN                NaN                    NaN
# 4            NaN               NaN                NaN                    NaN
#
#    appleStandHours  appleStandHoursGoal
# 0              NaN                  NaN
# 1              NaN                  NaN
# 2              NaN                  NaN
# 3              NaN                  NaN
# 4              NaN                  NaN
#
# [5 rows x 22 columns]

# %%
df_cleaned[df_cleaned['sourceName'] == 'Cronometer' ].describe()
# Out:
#              value  duration  activeEnergyBurned  activeEnergyBurnedGoal  \
# count  1755.000000       0.0                 0.0                     0.0
# mean     62.221815       NaN                 NaN                     NaN
# std     140.731053       NaN                 NaN                     NaN
# min       0.002400       NaN                 NaN                     NaN
# 25%       0.648000       NaN                 NaN                     NaN
# 50%       5.347500       NaN                 NaN                     NaN
# 75%      48.000000       NaN                 NaN                     NaN
# max    2039.520000       NaN                 NaN                     NaN
#
#        appleMoveTime  appleMoveTimeGoal  appleExerciseTime  \
# count            0.0                0.0                0.0
# mean             NaN                NaN                NaN
# std              NaN                NaN                NaN
# min              NaN                NaN                NaN
# 25%              NaN                NaN                NaN
# 50%              NaN                NaN                NaN
# 75%              NaN                NaN                NaN
# max              NaN                NaN                NaN
#
#        appleExerciseTimeGoal  appleStandHours  appleStandHoursGoal
# count                    0.0              0.0                  0.0
# mean                     NaN              NaN                  NaN
# std                      NaN              NaN                  NaN
# min                      NaN              NaN                  NaN
# 25%                      NaN              NaN                  NaN
# 50%                      NaN              NaN                  NaN
# 75%                      NaN              NaN                  NaN
# max                      NaN              NaN                  NaN

# %%
df_cleaned['type'].unique()
# Out:
# array([None, 'DietaryWater', 'Height', 'BodyMass', 'HeartRate',
#        'RespiratoryRate', 'BodyFatPercentage', 'StepCount',
#        'DistanceWalkingRunning', 'BasalEnergyBurned',
#        'ActiveEnergyBurned', 'FlightsClimbed', 'DietaryFatTotal',
#        'DietaryFatPolyunsaturated', 'DietaryFatMonounsaturated',
#        'DietaryFatSaturated', 'DietaryCholesterol', 'DietarySodium',
#        'DietaryCarbohydrates', 'DietaryFiber', 'DietarySugar',
#        'DietaryEnergyConsumed', 'DietaryProtein', 'DietaryVitaminA',
#        'DietaryVitaminB6', 'DietaryVitaminB12', 'DietaryVitaminC',
#        'DietaryVitaminD', 'DietaryVitaminE', 'DietaryVitaminK',
#        'DietaryCalcium', 'DietaryIron', 'DietaryThiamin',
#        'DietaryRiboflavin', 'DietaryNiacin', 'DietaryFolate',
#        'DietaryBiotin', 'DietaryPantothenicAcid', 'DietaryPhosphorus',
#        'DietaryIodine', 'DietaryMagnesium', 'DietaryZinc',
#        'DietarySelenium', 'DietaryCopper', 'DietaryManganese',
#        'DietaryChromium', 'DietaryMolybdenum', 'DietaryPotassium',
#        'AppleExerciseTime', 'DistanceCycling', 'RestingHeartRate',
#        'VO2Max', 'WalkingHeartRateAverage', 'EnvironmentalAudioExposure',
#        'HeadphoneAudioExposure', 'WalkingDoubleSupportPercentage',
#        'SixMinuteWalkTestDistance', 'AppleStandTime', 'WalkingSpeed',
#        'WalkingStepLength', 'WalkingAsymmetryPercentage',
#        'HKDataTypeSleepDurationGoal', 'AppleWalkingSteadiness',
#        'HeartRateRecoveryOneMinute', 'RunningSpeed', 'SleepAnalysis',
#        'AppleStandHour', 'HeartRateVariabilitySDNN'], dtype=object)

# %%
df_cleaned[df_cleaned['type'] == 'HeartRateRecoveryOneMinute' ]
# Out:
#           value                        type              sourceName  \
# 800926  52.5256  HeartRateRecoveryOneMinute  Jonathan’s Apple Watch
# 800927  52.5250  HeartRateRecoveryOneMinute  Jonathan’s Apple Watch
# 800928  52.5250  HeartRateRecoveryOneMinute  Jonathan’s Apple Watch
# 800929  52.5250  HeartRateRecoveryOneMinute  Jonathan’s Apple Watch
# 800930  52.5250  HeartRateRecoveryOneMinute  Jonathan’s Apple Watch
# 800931  52.5250  HeartRateRecoveryOneMinute  Jonathan’s Apple Watch
# 800932  41.1842  HeartRateRecoveryOneMinute  Jonathan’s Apple Watch
# 800933  44.9048  HeartRateRecoveryOneMinute  Jonathan’s Apple Watch
# 800934  44.9042  HeartRateRecoveryOneMinute  Jonathan’s Apple Watch
# 800935  44.9042  HeartRateRecoveryOneMinute  Jonathan’s Apple Watch
#
#         sourceVersion device       unit              creationDate  \
# 800926  2780.0.28.0.2   None  count/min 2023-01-16 16:42:31-07:00
# 800927  2780.0.28.0.2   None  count/min 2023-01-17 15:25:13-07:00
# 800928  2780.0.28.0.2   None  count/min 2023-01-23 07:13:21-07:00
# 800929      2780.0.35   None  count/min 2023-01-28 12:47:46-07:00
# 800930      2780.0.35   None  count/min 2023-02-03 14:25:46-07:00
# 800931      2780.0.35   None  count/min 2023-02-05 16:51:17-07:00
# 800932      2780.0.35   None  count/min 2023-02-20 14:00:46-07:00
# 800933      2780.0.35   None  count/min 2023-02-21 11:13:53-07:00
# 800934      2780.0.35   None  count/min 2023-02-27 16:45:01-07:00
# 800935      2780.0.35   None  count/min 2023-03-05 13:36:14-07:00
#
#                        startDate                   endDate  \
# 800926 2023-01-16 16:38:17-07:00 2023-01-16 16:38:17-07:00
# 800927 2023-01-17 15:22:58-07:00 2023-01-17 15:22:58-07:00
# 800928 2023-01-23 07:13:10-07:00 2023-01-23 07:13:10-07:00
# 800929 2023-01-28 12:47:42-07:00 2023-01-28 12:47:42-07:00
# 800930 2023-02-03 14:25:41-07:00 2023-02-03 14:25:41-07:00
# 800931 2023-02-05 16:51:12-07:00 2023-02-05 16:51:12-07:00
# 800932 2023-02-20 14:00:34-07:00 2023-02-20 14:00:34-07:00
# 800933 2023-02-21 11:13:49-07:00 2023-02-21 11:13:49-07:00
# 800934 2023-02-27 16:44:49-07:00 2023-02-27 16:44:49-07:00
# 800935 2023-03-05 13:36:07-07:00 2023-03-05 13:36:07-07:00
#
#        workoutActivityType  ...  dateComponents activeEnergyBurned  \
# 800926                None  ...            None                NaN
# 800927                None  ...            None                NaN
# 800928                None  ...            None                NaN
# 800929                None  ...            None                NaN
# 800930                None  ...            None                NaN
# 800931                None  ...            None                NaN
# 800932                None  ...            None                NaN
# 800933                None  ...            None                NaN
# 800934                None  ...            None                NaN
# 800935                None  ...            None                NaN
#
#        activeEnergyBurnedGoal  activeEnergyBurnedUnit  appleMoveTime  \
# 800926                    NaN                    None            NaN
# 800927                    NaN                    None            NaN
# 800928                    NaN                    None            NaN
# 800929                    NaN                    None            NaN
# 800930                    NaN                    None            NaN
# 800931                    NaN                    None            NaN
# 800932                    NaN                    None            NaN
# 800933                    NaN                    None            NaN
# 800934                    NaN                    None            NaN
# 800935                    NaN                    None            NaN
#
#        appleMoveTimeGoal  appleExerciseTime  appleExerciseTimeGoal  \
# 800926               NaN                NaN                    NaN
# 800927               NaN                NaN                    NaN
# 800928               NaN                NaN                    NaN
# 800929               NaN                NaN                    NaN
# 800930               NaN                NaN                    NaN
# 800931               NaN                NaN                    NaN
# 800932               NaN                NaN                    NaN
# 800933               NaN                NaN                    NaN
# 800934               NaN                NaN                    NaN
# 800935               NaN                NaN                    NaN
#
#         appleStandHours  appleStandHoursGoal
# 800926              NaN                  NaN
# 800927              NaN                  NaN
# 800928              NaN                  NaN
# 800929              NaN                  NaN
# 800930              NaN                  NaN
# 800931              NaN                  NaN
# 800932              NaN                  NaN
# 800933              NaN                  NaN
# 800934              NaN                  NaN
# 800935              NaN                  NaN
#
# [10 rows x 22 columns]
